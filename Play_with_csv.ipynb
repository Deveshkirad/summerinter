# %%
#sqewrthyjuki
print("hi ")
# Out:
# hi

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("nba.csv")
print(df.head())
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
print(pd.options.display.max_rows)
# Out:
# 60

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    str
#  1   Team      457 non-null    str
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    str
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    str
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    str
#  8   Salary    446 non-null    float64
# dtypes: float64(4), str(5)
# memory usage: 32.3 KB
# None

# %%
new_df=df.dropna()
#print(new_df)

print(new_df.info())
# Out:
# <class 'pandas.DataFrame'>
# Index: 364 entries, 0 to 456
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      364 non-null    str
#  1   Team      364 non-null    str
#  2   Number    364 non-null    float64
#  3   Position  364 non-null    str
#  4   Age       364 non-null    float64
#  5   Height    364 non-null    str
#  6   Weight    364 non-null    float64
#  7   College   364 non-null    str
#  8   Salary    364 non-null    float64
# dtypes: float64(4), str(5)
# memory usage: 28.4 KB
# None

# %%
print(df.aggregate({"Number":["min","max","mean"],
                    "Salary":["min","max","mean"],
                    "Age":["min","mean"]}))
# Out:
#          Number        Salary        Age
# min    0.000000  3.088800e+04  19.000000
# max   99.000000  2.500000e+07        NaN
# mean  17.678337  4.842684e+06  26.938731

# %%
print(df.mean(numeric_only=True, axis=0))
# Out:
# Number    1.767834e+01
# Age       2.693873e+01
# Weight    2.215230e+02
# Salary    4.842684e+06
# dtype: float64

# %%
df['try_column']=1
print(df.head())
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary  try_column
# 0              Texas  7730337.0           1
# 1          Marquette  6796117.0           1
# 2  Boston University        NaN           1
# 3      Georgia State  1148640.0           1
# 4                NaN  5000000.0           1

# %%
df=pd.read_csv("nba.csv",index_col="Name")
print(df.head())

df.drop(["Avery Bradley"],inplace=True)
print(df.head())
# Out:
#                          Team  Number Position   Age Height  Weight  \
# Name
# Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# Jae Crowder    Boston Celtics    99.0       SF  25.0    6-6   235.0
# John Holland   Boston Celtics    30.0       SG  27.0    6-5   205.0
# R.J. Hunter    Boston Celtics    28.0       SG  22.0    6-5   185.0
# Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#                          College     Salary
# Name
# Avery Bradley              Texas  7730337.0
# Jae Crowder            Marquette  6796117.0
# John Holland   Boston University        NaN
# R.J. Hunter        Georgia State  1148640.0
# Jonas Jerebko                NaN  5000000.0
#                          Team  Number Position   Age Height  Weight  \
# Name
# Jae Crowder    Boston Celtics    99.0       SF  25.0    6-6   235.0
# John Holland   Boston Celtics    30.0       SG  27.0    6-5   205.0
# ...

# %%
df["try_column"]=1
print(df.head())    

df.drop("try_column",axis=1,inplace=True)
print(df.head())
# Out:
#                          Team  Number Position   Age Height  Weight  \
# Name
# Jae Crowder    Boston Celtics    99.0       SF  25.0    6-6   235.0
# John Holland   Boston Celtics    30.0       SG  27.0    6-5   205.0
# R.J. Hunter    Boston Celtics    28.0       SG  22.0    6-5   185.0
# Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# Amir Johnson   Boston Celtics    90.0       PF  29.0    6-9   240.0
#
#                          College      Salary  try_column
# Name
# Jae Crowder            Marquette   6796117.0           1
# John Holland   Boston University         NaN           1
# R.J. Hunter        Georgia State   1148640.0           1
# Jonas Jerebko                NaN   5000000.0           1
# Amir Johnson                 NaN  12000000.0           1
#                          Team  Number Position   Age Height  Weight  \
# Name
# Jae Crowder    Boston Celtics    99.0       SF  25.0    6-6   235.0
# ...

# %%
df = pd.DataFrame({"A":[12, 4, 5, None, 1], 
                   "B":[7, 2, 54, 3, None], 
                   "C":[20, 16, 11, 3, 8], 
                   "D":[14, 3, None, 2, 6]}) 

index_ = ['Row_1', 'Row_2', 'Row_3', 'Row_4', 'Row_5']

df.index = index_

print(df)

result = df.truncate(before = 'Row_3', after = 'Row_4')
print(result)
# Out:
#           A     B   C     D
# Row_1  12.0   7.0  20  14.0
# Row_2   4.0   2.0  16   3.0
# Row_3   5.0  54.0  11   NaN
# Row_4   NaN   3.0   3   2.0
# Row_5   1.0   NaN   8   6.0
#          A     B   C    D
# Row_3  5.0  54.0  11  NaN
# Row_4  NaN   3.0   3  2.0

# %%
display(df.head())
df.sort_values("A",ascending=True,inplace=True)
display(df.head())
# Out:
#           A     B   C     D
# Row_1  12.0   7.0  20  14.0
# Row_3   5.0  54.0  11   NaN
# Row_2   4.0   2.0  16   3.0
# Row_5   1.0   NaN   8   6.0
# Row_4   NaN   3.0   3   2.0
#           A     B   C     D
# Row_5   1.0   NaN   8   6.0
# Row_2   4.0   2.0  16   3.0
# Row_3   5.0  54.0  11   NaN
# Row_1  12.0   7.0  20  14.0
# Row_4   NaN   3.0   3   2.0

# %%
df_csv=pd.read_csv("nba.csv")
print(df_csv.head())
print("\n\n")
print(df_csv.groupby('Name').groups)
print("\n\n ")
print(df_csv.groupby('Team').groups)

gk=df_csv.groupby("Name")
gk.first()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0
#
#
#
# ...

# %%
df_csv.groupby(['Name',"Age"]).sum()
# Out:
#                                         Team  Number Position Height  Weight  \
# Name            Age
# Aaron Brooks    31.0           Chicago Bulls     0.0       PG    6-0   161.0
# Aaron Gordon    20.0           Orlando Magic     0.0       PF    6-9   220.0
# Aaron Harrison  21.0       Charlotte Hornets     9.0       SG    6-6   210.0
# Adreian Payne   25.0  Minnesota Timberwolves    33.0       PF   6-10   237.0
# Al Horford      30.0           Atlanta Hawks    15.0        C   6-10   245.0
# ...                                      ...     ...      ...    ...     ...
# Wilson Chandler 29.0          Denver Nuggets    21.0       SF    6-8   225.0
# Xavier Munford  24.0       Memphis Grizzlies    14.0       PG    6-3   180.0
# Zach LaVine     21.0  Minnesota Timberwolves     8.0       PG    6-5   189.0
# Zach Randolph   34.0       Memphis Grizzlies    50.0       PF    6-9   260.0
# Zaza Pachulia   32.0        Dallas Mavericks    27.0        C   6-11   275.0
#
# ...

# %%
grp = df_csv.groupby('Name')
for name, group in grp:
    print(name)
    print(group)
    print()
# Out:
# Aaron Brooks
#              Name           Team  Number Position   Age Height  Weight  \
# 152  Aaron Brooks  Chicago Bulls     0.0       PG  31.0    6-0   161.0
#
#     College     Salary
# 152  Oregon  2250000.0
#
# Aaron Gordon
#              Name           Team  Number Position   Age Height  Weight  \
# 356  Aaron Gordon  Orlando Magic     0.0       PF  20.0    6-9   220.0
#
#      College     Salary
# 356  Arizona  4171680.0
#
# Aaron Harrison
#                Name               Team  Number Position   Age Height  Weight  \
# 328  Aaron Harrison  Charlotte Hornets     9.0       SG  21.0    6-6   210.0
#
#       College    Salary
# 328  Kentucky  525093.0
#
# Adreian Payne
#               Name                    Team  Number Position   Age Height  \
# 404  Adreian Payne  Minnesota Timberwolves    33.0       PF  25.0   6-10
#
#      Weight         College     Salary
# 404   237.0  Michigan State  1938840.0
#
# Al Horford
# ...

# %%
grp = df_csv.groupby(['Name', 'Age'])
for name, group in grp:
    print(name)
    print(group)
    print()
# Out:
# ('Aaron Brooks', 31.0)
#              Name           Team  Number Position   Age Height  Weight  \
# 152  Aaron Brooks  Chicago Bulls     0.0       PG  31.0    6-0   161.0
#
#     College     Salary
# 152  Oregon  2250000.0
#
# ('Aaron Gordon', 20.0)
#              Name           Team  Number Position   Age Height  Weight  \
# 356  Aaron Gordon  Orlando Magic     0.0       PF  20.0    6-9   220.0
#
#      College     Salary
# 356  Arizona  4171680.0
#
# ('Aaron Harrison', 21.0)
#                Name               Team  Number Position   Age Height  Weight  \
# 328  Aaron Harrison  Charlotte Hornets     9.0       SG  21.0    6-6   210.0
#
#       College    Salary
# 328  Kentucky  525093.0
#
# ('Adreian Payne', 25.0)
#               Name                    Team  Number Position   Age Height  \
# 404  Adreian Payne  Minnesota Timberwolves    33.0       PF  25.0   6-10
#
#      Weight         College     Salary
# 404   237.0  Michigan State  1938840.0
#
# ('Al Horford', 30.0)
# ...

# %%
grp = df_csv.groupby(['Name', 'Age'])
grp.get_group(('Aaron Gordon', 20.0))
# Out:
#              Name           Team  Number Position   Age Height  Weight  \
# 356  Aaron Gordon  Orlando Magic     0.0       PF  20.0    6-9   220.0
#
#      College     Salary
# 356  Arizona  4171680.0

# %%
grp1 = df_csv.groupby('Name')
grp1['Age'].aggregate(np.sum)
# Out:
# Name
# Aaron Brooks       31.0
# Aaron Gordon       20.0
# Aaron Harrison     21.0
# Adreian Payne      25.0
# Al Horford         30.0
#                    ...
# Wilson Chandler    29.0
# Xavier Munford     24.0
# Zach LaVine        21.0
# Zach Randolph      34.0
# Zaza Pachulia      32.0
# Name: Age, Length: 457, dtype: float64
